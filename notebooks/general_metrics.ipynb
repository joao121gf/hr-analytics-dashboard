# %% [markdown]
# ## 📊 1. Métricas Gerais da Empresa
# - Total de funcionários ativos e desligados
#
# - Distribuição por departamento (Department)
#
# - Distribuição por cargo (Position)
#
# - Média salarial por departamento e cargo
#
# - Tempo médio de permanência na empresa
#
# - Média de absenteísmo (Absences)
#
# - Média de atrasos nos últimos 30 dias (DaysLateLast30)

# %% [markdown]
# - Neste arquivo importaremos um CSV (general_metrics.csv) com as sequintes métricas:
# - Total de Funcionários Ativos
# - Total de Funcionários Desligados
# - Tempo Médio de Permanência
# - Média de Absenteísmo
# - Média de Atrasos Últimos 30 dias

# %%
import pandas as pd
from IPython.display import display
from datetime import datetime
df = pd.read_csv('../data/filtred/filtred_hr_dataset.csv')
display(df.head(2))
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                 2019-01-17              0        1
# ...

# %% [markdown]
# - Quantidade de funcionários ativos e desligados

# %%
# Conta ativos e desligados
total_ativos = df[df['Termd'] == 0].shape[0]
total_desligados = df[df['Termd'] == 1].shape[0]

# Cria o novo DataFrame com colunas 'Métrica' e 'Valor'
general_df2 = pd.DataFrame({
    'Métrica': ['Total de Funcionários Ativos', 'Total de Funcionários Desligados'],
    'Valor': [total_ativos, total_desligados]
})

display(general_df2)

inatives = df[df['Termd'] == 0]
# Out:
#                             Métrica  Valor
# 0      Total de Funcionários Ativos    207
# 1  Total de Funcionários Desligados    104

# %%
display(df[df['Termd'] == 1])
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# 10       Baczenski, Rachael    10252          1                1         0
# 11            Barbara, Thomas  10242          1                1         1
# ..                        ...    ...        ...              ...       ...
# 301             Wilber, Barry  10048          1                1         1
# 302             Wilkes, Annie  10204          0                2         0
# 303     Williams, Jacquelyn    10264          0                0         0
# 304        Winthrop, Jordan    10033          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
#
# ...

# %% [markdown]
# - Tempo médio de permanência

# %%
# Data de admissão está na coluna: DateofHire
# Data de encerramento (desligamento) está na coluna: DateofTerminationDateofHire

# %%
print((df['DateofHire'].dtype))
print((df['DateofTermination'].dtype))
# Out:
# object
# object

# %%
df['DateofHire'] = pd.to_datetime(df['DateofHire'], errors='coerce')
df['DateofTermination'] = pd.to_datetime(df['DateofTermination'], errors='coerce')

# %%
print((df['DateofHire'].dtype))
print((df['DateofTermination'].dtype))
# Out:
# datetime64[ns]
# datetime64[ns]

# %%
inatives = df[df['Termd'] == 1].copy()  
atives = df[df['Termd'] == 0].copy()

inatives.loc[:, 'DateofHire'] = pd.to_datetime(inatives['DateofHire'], errors='coerce')
inatives.loc[:, 'DateofTermination'] = pd.to_datetime(inatives['DateofTermination'], errors='coerce')

inatives.loc[:, 'time_permanency'] = (inatives['DateofTermination'] - inatives['DateofHire']).dt.days
display(inatives.head(2))
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
#
#    ManagerID  RecruitmentSource PerformanceScore EngagementSurvey  \
# 1        4.0             Indeed      Fully Meets             4.96
# 2       20.0           LinkedIn      Fully Meets             3.02
#
#    EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# 1                3                    6                 2016-02-24
# 2                3                    0                 2012-05-15
#
#   DaysLateLast30 Absences time_permanency
# 1              0       17             444
# ...

# %%
general_df2.loc[len(general_df2)] = ['Tempo medio permanencia', int(inatives['time_permanency'].mean())]
general_df2['Valor'] = general_df2['Valor'].astype(int)

# %%
display(general_df2)
# Out:
#                             Métrica  Valor
# 0      Total de Funcionários Ativos    207
# 1  Total de Funcionários Desligados    104
# 2           Tempo medio permanencia   1264

# %% [markdown]
# - Índice de Absenteísmo

# %%
# Apenas funcionários ativos
ativos = df[df['Termd'] == 0].copy()

# Calcular tempo de permanência em dias até hoje
from datetime import datetime
today = pd.to_datetime('today')

ativos['DateofHire'] = pd.to_datetime(ativos['DateofHire'], errors='coerce')
ativos['days_in_company'] = (today - ativos['DateofHire']).dt.days

# Calcular faltas por mês (normalizado)
ativos['absences_total_days'] = ativos['Absences']  # total acumulado
ativos['absences_per_month'] = ativos['absences_total_days'] / (ativos['days_in_company'] / 30)

# Converter faltas por mês em horas
ativos['absences_hours_per_month'] = ativos['absences_per_month'] * 8

# Total de horas previstas por mês por funcionário
hora_prev_mensal = 176

# Índice médio de absenteísmo (%)
ativos['abs_percent'] = (ativos['absences_hours_per_month'] / hora_prev_mensal) * 100
mean_abs = round(ativos['abs_percent'].mean(), 2)


display(mean_abs)
# Out:
# np.float64(0.32)

# %%
# general_df2.loc[len(general_df2)] = ['Tempo medio permanencia', int(inatives['time_permanency'].mean())]
# general_df2['Valor'] = general_df2['Valor'].astype(int)


general_df2.loc[len(general_df2)] = ['Índice de Absenteísmo', mean_abs]
display(general_df2)
# Out:
#                             Métrica    Valor
# 0      Total de Funcionários Ativos   207.00
# 1  Total de Funcionários Desligados   104.00
# 2           Tempo medio permanencia  1264.00
# 3             Índice de Absenteísmo     0.32

# %%
# Média de atrasos nos últimos 30 dias (`DaysLateLast30`)
display(df.head(1))
mean_days_late_last_30 = round(df['DaysLateLast30'].mean(), 2)
display(mean_days_late_last_30)
# Out:
#          Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0  Adinolfi, Wilson  K  10026          0                0         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0               4.6               5                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                 2019-01-17              0        1
#
# [1 rows x 36 columns]
# np.float64(0.41)

# %%
general_df2.loc[len(general_df2)] = ['Média de atrasos nos últimos 30 dias', mean_days_late_last_30]
display(general_df2)
# Out:
#                                 Métrica    Valor
# 0          Total de Funcionários Ativos   207.00
# 1      Total de Funcionários Desligados   104.00
# 2               Tempo medio permanencia  1264.00
# 3                 Índice de Absenteísmo     0.32
# 4  Média de atrasos nos últimos 30 dias     0.41

# %%
# Exportando df para csv
general_df2.to_csv('general_metrics.csv', index=False)
